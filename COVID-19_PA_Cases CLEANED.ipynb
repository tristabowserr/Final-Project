# %%
import pandas as pd

# %%
df = pd. read_csv('COVID-19_PA_Cases.csv')

# %%
df.head(10)
# Out:
#    Jurisdiction        Date  New Cases  7-day Average New Cases  \
# 0        Centre  03/05/2020          0                      NaN
# 1        Lehigh  03/13/2021         71                     82.1
# 2       Luzerne  08/04/2020         26                     20.7
# 3  Pennsylvania  08/04/2020        754                    814.7
# 4         Berks  10/29/2020         94                    112.4
# 5        Monroe  07/28/2020          8                      5.1
# 6        Monroe  08/18/2020          4                      3.4
# 7         Union  05/30/2020          0                      0.7
# 8         Union  07/08/2020          0                      0.6
# 9  Philadelphia  01/20/2021        542                    512.4
#
#    Cumulative cases                            Population (2019)  \
# 0                                           0             162385
# 1                                       31915             369318
# ...

# %%
df.tail(10)
# Out:
#       Jurisdiction        Date  New Cases  7-day Average New Cases  \
# 27326       Snyder  09/01/2020          2                      3.0
# 27327          Elk  10/06/2020          0                      1.0
# 27328          Elk  10/28/2020          4                      5.3
# 27329          Elk  10/11/2020          1                      0.9
# 27330       Snyder  08/23/2020          1                      1.9
# 27331       Snyder  08/13/2020          3                      2.7
# 27332       Snyder  08/11/2020          3                      2.1
# 27333          Elk  11/06/2020         12                     12.4
# 27334       Snyder  08/10/2020          5                      1.7
# 27335       Snyder  07/27/2020          3                      1.1
#
#        Cumulative cases                            Population (2019)  \
# 27326                                         176              40372
# 27327                                          87              29910
# ...

# %%
df.sample(10)
# Out:
#        Jurisdiction        Date  New Cases  7-day Average New Cases  \
# 558          Carbon  12/04/2020         70                     46.0
# 18667        Greene  03/27/2020          2                      0.9
# 596        Columbia  11/18/2020          7                     15.1
# 9806        Venango  05/14/2020          0                      0.0
# 7783   Pennsylvania  03/30/2021       4372                   4054.3
# 24637        Greene  06/24/2020          0                      0.7
# 26126         Perry  12/19/2020         28                     35.3
# 24722     Lancaster  12/19/2020        286                    359.3
# 550        Delaware  08/20/2020         38                     56.6
# 4651          Berks  10/02/2020         39                     41.4
#
#        Cumulative cases                            Population (2019)  \
# 558                                          1641              64182
# 18667                                           6              36233
# ...

# %%
df.columns
# Out:
# Index(['Jurisdiction', 'Date', 'New Cases', '7-day Average New Cases',
#        'Cumulative cases                          ', 'Population (2019)',
#        'New Case Rate', '7-Day Average New Case Rate', 'Cumulative Case Rate',
#        'County FIPS Code', 'Longitude', 'Latitude',
#        'Georeferenced Lat & Long'],
#       dtype='object')

# %%
dfMini=(['Jurisdiction', 'Date', 'New Cases', 'Cumulative Cases', 'Population (2019)', 'New Case Rate','Cumulative Case Rat'])

# %%
dfMini.to_csv('COVID-19_PA_Cases.csv', encoding='utf8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-b61a80102371> in <module>
# ----> 1 dfMini.to_csv('COVID-19_PA_Cases.csv', encoding='utf8')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
pwd
# Out:
# '/Users/Troubs/Desktop/pythonforjournalists'

# %%
df.sample()
# Out:
#       Jurisdiction        Date  New Cases  7-day Average New Cases  \
# 26177   Huntingdon  06/20/2020          0                      0.1
#
#        Cumulative cases                            Population (2019)  \
# 26177                                         243              45144
#
#        New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# 26177            0.0                          0.3                 538.3
#
#        County FIPS Code  Longitude   Latitude       Georeferenced Lat & Long
# 26177             42061 -77.982766  40.416105  POINT (-77.9827661 40.416105)

# %%
df = df.drop('7-day Average New Cases', 1)

# %%
df.sample()
# Out:
#      Jurisdiction        Date  New Cases  \
# 2472        Union  04/29/2020          2
#
#       Cumulative cases                            Population (2019)  \
# 2472                                          28              44923
#
#       New Case Rate  7-Day Average New Case Rate  Cumulative Case Rate  \
# 2472            4.5                          1.6                  62.3
#
#       County FIPS Code  Longitude   Latitude          Georeferenced Lat & Long
# 2472             42119 -77.064158  40.964731  POINT (-77.06415803 40.96473131)

# %%
df = df.drop('7-Day Average New Case Rate', 1)

# %%
df = df.drop('County FIPS Code', 1)

# %%
df = df.drop('Longitude', 1)

# %%
df = df.drop('Latitude', 1)

# %%
df = df.drop('Georeferenced Lat & Long', 1)

# %%
dfMini.to_csv('COVID-19_PA_Cases.csv', encoding='utf8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-b61a80102371> in <module>
# ----> 1 dfMini.to_csv('COVID-19_PA_Cases.csv', encoding='utf8')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
df.sample()
# Out:
#        Jurisdiction        Date  New Cases  \
# 19036  Westmoreland  08/15/2020          9
#
#        Cumulative cases                            Population (2019)  \
# 19036                                        1636             348899
#
#        New Case Rate  Cumulative Case Rate
# 19036            2.6                 468.9
