# %% [markdown]
# # Effects of Social Media on College Students

# %%
import pandas as pd

# %%
df = pd.read_csv('socialmediacollege.csv')
df.head(10)
# Out:
#   Gender age range geographical zone      Academic Status  \
# 0   Male   15 - 25   North West (NW)  Student - Full time
# 1   Male   15 - 25   South West (SW)  Student - Full time
# 2   Male   26 - 35   South West (SW)  Student - Full time
# 3   Male   15 - 25   South West (SW)  Student - Full time
# 4   Male   26 - 35   South West (SW)  Student - Full time
# 5   Male   15 - 25   South West (SW)  Student - Full time
# 6   Male   15 - 25   South West (SW)  Student - Full time
# 7   Male   15 - 25   North East (NE)  Student - Full time
# 8   Male   15 - 25   South West (SW)  Student - Full time
# 9   Male   15 - 25   South West (SW)  Student - Full time
#
#    Education Level/Certificates (You can choose more than one)  \
# 0    SSCE;OND;Undegraduate (presently in University)
# 1        SSCE;First Degree (BSc, B.Tech, B.Edu, ...)
# 2        SSCE;Undegraduate (presently in University)
# 3             First Degree (BSc, B.Tech, B.Edu, ...)
# ...

# %%
df.tail(10)
# Out:
#      Gender age range   geographical zone  \
# 840    Male   15 - 25  North Central (NC)
# 841    Male   15 - 25     South West (SW)
# 842    Male   15 - 25     South West (SW)
# 843    Male   15 - 25     South West (SW)
# 844  Female   15 - 25     South East (SE)
# 845    Male   15 - 25  North Central (NC)
# 846  Female   26 - 35     North West (NW)
# 847  Female   15 - 25     North East (NE)
# 848    Male   26 - 35     North West (NW)
# 849    Male   15 - 25     North West (NW)
#
#                               Academic Status  \
# 840                       Student - Full time
# 841                       Student - Full time
# 842                       Student - Full time
# 843                       Student - Full time
# 844                       Student - Full time
# 845                       Student - Full time
# 846                       Student - Full time
# 847  Student - Part time or Distance Learning
# 848                       Student - Full time
# ...

# %%
df.sample(10)
# Out:
#      Gender age range geographical zone      Academic Status  \
# 790    Male   15 - 25   South West (SW)  Student - Full time
# 56     Male   15 - 25   South West (SW)  Student - Full time
# 849    Male   15 - 25   North West (NW)  Student - Full time
# 428    Male   15 - 25   South West (SW)  Student - Full time
# 84   Female   15 - 25   South West (SW)  Student - Full time
# 450    Male   15 - 25   South West (SW)  Student - Full time
# 474    Male   26 - 35   South West (SW)         Non Students
# 600  Female   15 - 25   South West (SW)  Student - Full time
# 174    Male   15 - 25  South South (SS)  Student - Full time
# 55     Male   15 - 25   South West (SW)  Student - Full time
#
#      Education Level/Certificates (You can choose more than one)  \
# 790        SSCE;Undegraduate (presently in University)
# 56              Undegraduate (presently in University)
# 849                                       SSCE;NCE;OND
# 428        SSCE;Undegraduate (presently in University)
# ...

# %%
df.dtypes
# Out:
# Gender                                                                                                                                                     object
# age range                                                                                                                                                  object
# geographical zone                                                                                                                                          object
# Academic Status                                                                                                                                            object
#  Education Level/Certificates (You can choose more than one)                                                                                               object
# social Media Platforms                                                                                                                                     object
# ...

# %%
df.shape
# Out:
# (850, 31)

# %%
df.describe()
# Out:
#        Gender age range geographical zone      Academic Status  \
# count     850       850               850                  850
# unique      2         3                 6                    3
# top      Male   15 - 25   South West (SW)  Student - Full time
# freq      575       725               513                  795
#
#         Education Level/Certificates (You can choose more than one)  \
# count                                                 850
# unique                                                 33
# top           SSCE;Undegraduate (presently in University)
# freq                                                  495
#
#                                   social Media Platforms   \
# count                                                 850
# unique                                                242
# top     Facebook;Twitter;Instagram;WhatsApp;Telegram;S...
# freq                                                  103
#
#         emerging technologies   \
# ...

# %%
df['ValueClean'] = df['Are you presently involved in e-learning using any social media platform or emerging technologies earlier highlighted?'].str.replace('Yes', 'Y')

# %%
df.head()
# Out:
#   Gender age range geographical zone      Academic Status  \
# 0   Male   15 - 25   North West (NW)  Student - Full time
# 1   Male   15 - 25   South West (SW)  Student - Full time
# 2   Male   26 - 35   South West (SW)  Student - Full time
# 3   Male   15 - 25   South West (SW)  Student - Full time
# 4   Male   26 - 35   South West (SW)  Student - Full time
#
#    Education Level/Certificates (You can choose more than one)  \
# 0    SSCE;OND;Undegraduate (presently in University)
# 1        SSCE;First Degree (BSc, B.Tech, B.Edu, ...)
# 2        SSCE;Undegraduate (presently in University)
# 3             First Degree (BSc, B.Tech, B.Edu, ...)
# 4  SSCE;Undegraduate (presently in University);Fi...
#
#                              social Media Platforms   \
# 0  Facebook;Twitter;Instagram;WhatsApp;Telegram;L...
# 1               Facebook;Instagram;WhatsApp;Telegram
# 2  Facebook;Twitter;Instagram;WhatsApp;Telegram;L...
# 3  Facebook;Twitter;Instagram;WhatsApp;Telegram;L...
# ...

# %%
(https://data.mendeley.com/datasets/vb2m5x5xhr/3)
# Out:
#   File "<ipython-input-25-642642e0ea17>", line 1
#     (https://data.mendeley.com/datasets/vb2m5x5xhr/3)
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# This dataset goes into detail about how college students feel having social media? Does it help them? From what the dataset showed, it looked as if many students see the benefits of social media rather than the negatives. Some questions that I would like to ask about this dataset is what social medias seemed to help the most and why? After I get to crunch the numbers, I am eager to see what the percentages are when it comes to how college students view social media.

# %%
df.head(10)
# Out:
#   Gender age range geographical zone      Academic Status  \
# 0   Male   15 - 25   North West (NW)  Student - Full time
# 1   Male   15 - 25   South West (SW)  Student - Full time
# 2   Male   26 - 35   South West (SW)  Student - Full time
# 3   Male   15 - 25   South West (SW)  Student - Full time
# 4   Male   26 - 35   South West (SW)  Student - Full time
# 5   Male   15 - 25   South West (SW)  Student - Full time
# 6   Male   15 - 25   South West (SW)  Student - Full time
# 7   Male   15 - 25   North East (NE)  Student - Full time
# 8   Male   15 - 25   South West (SW)  Student - Full time
# 9   Male   15 - 25   South West (SW)  Student - Full time
#
#    Education Level/Certificates (You can choose more than one)  \
# 0    SSCE;OND;Undegraduate (presently in University)
# 1        SSCE;First Degree (BSc, B.Tech, B.Edu, ...)
# 2        SSCE;Undegraduate (presently in University)
# 3             First Degree (BSc, B.Tech, B.Edu, ...)
# ...

# %%
df.tail(10)
# Out:
#      Gender age range   geographical zone  \
# 840    Male   15 - 25  North Central (NC)
# 841    Male   15 - 25     South West (SW)
# 842    Male   15 - 25     South West (SW)
# 843    Male   15 - 25     South West (SW)
# 844  Female   15 - 25     South East (SE)
# 845    Male   15 - 25  North Central (NC)
# 846  Female   26 - 35     North West (NW)
# 847  Female   15 - 25     North East (NE)
# 848    Male   26 - 35     North West (NW)
# 849    Male   15 - 25     North West (NW)
#
#                               Academic Status  \
# 840                       Student - Full time
# 841                       Student - Full time
# 842                       Student - Full time
# 843                       Student - Full time
# 844                       Student - Full time
# 845                       Student - Full time
# 846                       Student - Full time
# 847  Student - Part time or Distance Learning
# 848                       Student - Full time
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable
